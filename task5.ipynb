# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sales_data.csv")
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.shape

# %%
df.isnull().sum()

# %% [markdown]
# ## Data Exploration Summary
# - Dataset contains 8 rows and 6 columns
# - No missing values found
# - Data includes Sales, Profit, Product and Region information
# - Dataset is clean and ready for analysis

# %%
df.groupby("Product")["Sales"].sum().sort_values(ascending=False)

# %%
df.groupby("Region")["Sales"].sum()

# %%
df.groupby("Product")["Profit"].sum()

# %%
df.groupby("Product")["Sales"].sum().plot(kind="bar")
plt.title("Sales by Product")
plt.xlabel("Product")
plt.ylabel("Total Sales")
plt.show()

# %%
df.groupby("Region")["Sales"].sum().plot(kind="pie", autopct="%1.1f%%")
plt.title("Sales by Region")
plt.ylabel("")
plt.show()

# %%
df["Date"] = pd.to_datetime(df["Date"])
df.plot(x="Date", y="Sales", kind="line")
plt.title("Sales Trend Over Time")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# ## Key Insights
# - Laptop has highest total sales
# - Regional sales analysis highlights revenue contribution across different regions
# - Sales trend shows fluctuations across products
# - Dataset analysis helps identify top-performing categories

# %% [markdown]
# ## Conclusion
# This project demonstrates basic exploratory data analysis (EDA) using Python Pandas with visualization techniques for business insights.
